# %% [markdown]
# # Week 12 - Milestone Two week

# %% [markdown]
# # 1. Lesson: no lesson this week.  Milestone Two is due!

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Suppose you plot the number visitors to a museum over the seven days of a week; then again the following week.  Can you suggest the advantages and disadvantages of the following two ways of presenting the data?

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
time_series_0 = np.array([100, 110, 130, 120, 100, 90, 80])
time_series_1 = np.array([70, 90, 100, 100, 120, 110, 90])
fig, axs = plt.subplots(1, 2)
axs[0].plot(time_series_0)
axs[1].plot(time_series_1)
plt.subplots_adjust(wspace = 0)
plt.xlabel("Day of the week")
plt.ylabel("Number of visitors")
# Out:
# Text(0, 0.5, 'Number of visitors')

# %%
plt.plot(time_series_0)
plt.plot(time_series_1)
plt.xlabel("Day of the week")
plt.ylabel("Number of visitors")
# Out:
# Text(0, 0.5, 'Number of visitors')

# %% [markdown]
# ### Seperated lineplot
#
# #### Pros
# - seperate y axis scales
# - individually shows each week, clear seperation of each week
#
#
# #### Cons
# - seperate y axis scales, if not observant it looks as though the peaks were the same

# %% [markdown]
# ### Multiline lineplot
#
# #### Pros
# - different colors for each weekly time series
# - easy to comprehend different peaks across the weeks
#
#
# #### Cons
# - does not have labels for each time series
# - could be misinterpreted

# %% [markdown]
# # 3. Working on your datasets
#
# This week, you can work on Milestone Two rather than having a particular exercise about working on your datasets

# %% [markdown]
# # 4. Storytelling With Data plot
#
# Reproduce any graph of your choice in p. 187-205 of the Storytelling With Data book as best you can. (Chapter Eight). You do not have to get the exact data values right, just the overall look and feel.

# %%
import matplotlib.pyplot as plt

# Sample data
years = [2008, 2008]
prices = [400, 375]
labels = ['A', 'B']

plt.figure(figsize=(8, 4))

plt.scatter(years, prices, color='midnightblue', s=27)

# Add labels next to each point
for x, y, label in zip(years, prices, labels):
    plt.text(x - 0.3, y, label, va='center', ha='left', fontsize=10)

plt.title("Retail price over time", fontsize=12, loc='left')
plt.xlabel("Year", loc='left')
plt.ylabel("Average price", loc='top')

# Format y-axis as currency
plt.yticks(range(0, 601, 100), [f'${v}' for v in range(0, 601, 100)])

plt.xlim(2007, 2014)
plt.ylim(0, 500)

plt.grid(False)
plt.gca().spines[['top', 'right']].set_visible(False)

plt.show()
